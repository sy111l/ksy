# %% [markdown]
# <a href="https://colab.research.google.com/github/sy111l/ksy/blob/main/%EC%8B%A4%ED%97%98_%ED%85%80%ED%94%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.14.0)

# %%
import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM
from tensorflow.keras.utils import to_categorical


# 랜덤시드 고정시키기
np.random.seed(5)

# 손실 이력 클래스 정의
class LossHistory(keras.callbacks.Callback):
    def init(self):
        self.losses = []

    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))

# 데이터셋 생성 함수
def seq2dataset(seq, window_size):
    dataset_X = []
    dataset_Y = []

    for i in range(len(seq)-window_size):

        subset = seq[i:(i+window_size+1)]

        for si in range(len(subset)-1):
            features = code2features(subset[si])
            dataset_X.append(features)

        dataset_Y.append([code2idx[subset[window_size]]])

    return np.array(dataset_X), np.array(dataset_Y)

# 속성 변환 함수
def code2features(code):
    features = []
    features.append(code2scale[code[0]]/float(max_scale_value))
    features.append(code2length[code[1]])
    return features

# 1. 데이터 준비하기

# 코드 사전 정의

code2scale = {'c':0, 'd':1, 'e':2, 'f':3, 'g':4, 'a':5, 'b':6}
code2length = {'4':0, '8':1}

code2idx = {'c4':0, 'd4':1, 'e4':2, 'f4':3, 'g4':4, 'a4':5, 'b4':6,
            'c8':7, 'd8':8, 'e8':9, 'f8':10, 'g8':11, 'a8':12, 'b8':13}

idx2code = {0:'c4', 1:'d4', 2:'e4', 3:'f4', 4:'g4', 5:'a4', 6:'b4',
            7:'c8', 8:'d8', 9:'e8', 10:'f8', 11:'g8', 12:'a8', 13:'b8'}

max_scale_value = 6.0

# 시퀀스 데이터 정의
seq = ['g8', 'e8', 'e4', 'f8', 'd8', 'd4', 'c8', 'd8', 'e8', 'f8', 'g8', 'g8', 'g4',
       'g8', 'e8', 'e8', 'e8', 'f8', 'd8', 'd4', 'c8', 'e8', 'g8', 'g8', 'e8', 'e8', 'e4',
       'd8', 'd8', 'd8', 'd8', 'd8', 'e8', 'f4', 'e8', 'e8', 'e8', 'e8', 'e8', 'f8', 'g4',
       'g8', 'e8', 'e4', 'f8', 'd8', 'd4', 'c8', 'e8', 'g8', 'g8', 'e8', 'e8', 'e4']

# 2. 데이터셋 생성하기

x_train, y_train = seq2dataset(seq, window_size = 4)

# 입력을 (샘플 수, 타임스텝, 특성 수)로 형태 변환
x_train = np.reshape(x_train, (50, 4, 2))

# 라벨값에 대한 one-hot 인코딩 수행
y_train = to_categorical(y_train)

one_hot_vec_size = y_train.shape[1]

print("one hot encoding vector size is ", one_hot_vec_size)

# 3. 모델 구성하기
model = Sequential()
model.add(LSTM(128, batch_input_shape = (1, 4, 2), stateful=True))
model.add(Dense(one_hot_vec_size, activation='softmax'))

# 4. 모델 학습과정 설정하기
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# 5. 모델 학습시키기
num_epochs = 100

history = LossHistory() # 손실 이력 객체 생성
history.init()

for epoch_idx in range(num_epochs):
    print ('epochs : ' + str(epoch_idx) )
    model.fit(x_train, y_train, epochs=1, batch_size=1, verbose=2, shuffle=False, callbacks=[history]) # 50 is X.shape[0]
    model.reset_states()

# 6. 학습과정 살펴보기
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(history.losses)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# 7. 모델 평가하기
scores = model.evaluate(x_train, y_train, batch_size=1)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))
model.reset_states()

# 8. 모델 사용하기

pred_count = 50 # 최대 예측 개수 정의

# 한 스텝 예측

seq_out = ['g8', 'e8', 'e4', 'f8']
pred_out = model.predict(x_train, batch_size=1)

for i in range(pred_count):
    idx = np.argmax(pred_out[i]) # one-hot 인코딩을 인덱스 값으로 변환
    seq_out.append(idx2code[idx]) # seq_out는 최종 악보이므로 인덱스 값을 코드로 변환하여 저장

print("one step prediction : ", seq_out)

model.reset_states()

# 곡 전체 예측

seq_in = ['g8', 'e8', 'e4', 'f8']
seq_out = seq_in

seq_in_featrues = []

for si in seq_in:
    features = code2features(si)
    seq_in_featrues.append(features)

for i in range(pred_count):
    sample_in = np.array(seq_in_featrues)
    sample_in = np.reshape(sample_in, (1, 4, 2)) # 샘플 수, 타입스텝 수, 속성 수
    pred_out = model.predict(sample_in)
    idx = np.argmax(pred_out)
    seq_out.append(idx2code[idx])

    features = code2features(idx2code[idx])
    seq_in_featrues.append(features)
    seq_in_featrues.pop(0)

model.reset_states()

print("full song prediction : ", seq_out)
# Out:
# one hot encoding vector size is  12
# epochs : 0
# 50/50 - 2s - loss: 2.3424 - accuracy: 0.2600 - 2s/epoch - 37ms/step
# epochs : 1
# 50/50 - 0s - loss: 2.0025 - accuracy: 0.3400 - 179ms/epoch - 4ms/step
# epochs : 2
# 50/50 - 0s - loss: 1.9556 - accuracy: 0.3400 - 181ms/epoch - 4ms/step
# epochs : 3
# 50/50 - 0s - loss: 1.9400 - accuracy: 0.3400 - 177ms/epoch - 4ms/step
# epochs : 4
# 50/50 - 0s - loss: 1.9304 - accuracy: 0.3400 - 189ms/epoch - 4ms/step
# epochs : 5
# 50/50 - 0s - loss: 1.9230 - accuracy: 0.3400 - 174ms/epoch - 3ms/step
# epochs : 6
# 50/50 - 0s - loss: 1.9169 - accuracy: 0.3400 - 181ms/epoch - 4ms/step
# epochs : 7
# 50/50 - 0s - loss: 1.9116 - accuracy: 0.3400 - 181ms/epoch - 4ms/step
# epochs : 8
# 50/50 - 0s - loss: 1.9065 - accuracy: 0.3600 - 176ms/epoch - 4ms/step
# epochs : 9
# 50/50 - 0s - loss: 1.9014 - accuracy: 0.3600 - 199ms/epoch - 4ms/step
# epochs : 10
# 50/50 - 0s - loss: 1.8959 - accuracy: 0.3600 - 175ms/epoch - 3ms/step
# epochs : 11
# 50/50 - 0s - loss: 1.8896 - accuracy: 0.3600 - 182ms/epoch - 4ms/step
# epochs : 12
# 50/50 - 0s - loss: 1.8828 - accuracy: 0.3600 - 193ms/epoch - 4ms/step
# epochs : 13
# 50/50 - 0s - loss: 1.8748 - accuracy: 0.3600 - 269ms/epoch - 5ms/step
# epochs : 14
# 50/50 - 0s - loss: 1.8595 - accuracy: 0.3600 - 292ms/epoch - 6ms/step
# epochs : 15
# 50/50 - 0s - loss: 1.8319 - accuracy: 0.3800 - 318ms/epoch - 6ms/step
# epochs : 16
# 50/50 - 0s - loss: 1.8273 - accuracy: 0.3600 - 274ms/epoch - 5ms/step
# epochs : 17
# 50/50 - 0s - loss: 1.8458 - accuracy: 0.3400 - 298ms/epoch - 6ms/step
# epochs : 18
# 50/50 - 0s - loss: 1.9753 - accuracy: 0.3400 - 308ms/epoch - 6ms/step
# epochs : 19
# 50/50 - 0s - loss: 1.8594 - accuracy: 0.3600 - 295ms/epoch - 6ms/step
# epochs : 20
# 50/50 - 0s - loss: 1.8104 - accuracy: 0.3600 - 287ms/epoch - 6ms/step
# epochs : 21
# 50/50 - 0s - loss: 1.8269 - accuracy: 0.3400 - 285ms/epoch - 6ms/step
# epochs : 22
# 50/50 - 0s - loss: 1.8000 - accuracy: 0.3600 - 314ms/epoch - 6ms/step
# epochs : 23
# 50/50 - 0s - loss: 1.7630 - accuracy: 0.3200 - 191ms/epoch - 4ms/step
# epochs : 24
# 50/50 - 0s - loss: 1.7877 - accuracy: 0.3600 - 175ms/epoch - 3ms/step
# epochs : 25
# 50/50 - 0s - loss: 1.7562 - accuracy: 0.3600 - 183ms/epoch - 4ms/step
# epochs : 26
# 50/50 - 0s - loss: 1.7144 - accuracy: 0.3600 - 181ms/epoch - 4ms/step
# epochs : 27
# 50/50 - 0s - loss: 1.8443 - accuracy: 0.3400 - 179ms/epoch - 4ms/step
# epochs : 28
# 50/50 - 0s - loss: 1.6459 - accuracy: 0.3600 - 180ms/epoch - 4ms/step
# epochs : 29
# 50/50 - 0s - loss: 1.6117 - accuracy: 0.4600 - 191ms/epoch - 4ms/step
# epochs : 30
# 50/50 - 0s - loss: 1.6460 - accuracy: 0.3800 - 177ms/epoch - 4ms/step
# epochs : 31
# 50/50 - 0s - loss: 1.6888 - accuracy: 0.3800 - 183ms/epoch - 4ms/step
# epochs : 32
# 50/50 - 0s - loss: 1.6326 - accuracy: 0.4000 - 185ms/epoch - 4ms/step
# epochs : 33
# 50/50 - 0s - loss: 1.4672 - accuracy: 0.4800 - 187ms/epoch - 4ms/step
# epochs : 34
# 50/50 - 0s - loss: 1.4282 - accuracy: 0.4800 - 193ms/epoch - 4ms/step
# epochs : 35
# 50/50 - 0s - loss: 1.4044 - accuracy: 0.4600 - 186ms/epoch - 4ms/step
# epochs : 36
# 50/50 - 0s - loss: 1.3863 - accuracy: 0.5000 - 195ms/epoch - 4ms/step
# epochs : 37
# 50/50 - 0s - loss: 1.3967 - accuracy: 0.4600 - 189ms/epoch - 4ms/step
# epochs : 38
# 50/50 - 0s - loss: 1.4962 - accuracy: 0.4800 - 183ms/epoch - 4ms/step
# epochs : 39
# 50/50 - 0s - loss: 1.2831 - accuracy: 0.6000 - 189ms/epoch - 4ms/step
# epochs : 40
# 50/50 - 0s - loss: 1.2055 - accuracy: 0.5400 - 176ms/epoch - 4ms/step
# epochs : 41
# 50/50 - 0s - loss: 1.2963 - accuracy: 0.4800 - 190ms/epoch - 4ms/step
# epochs : 42
# 50/50 - 0s - loss: 1.0613 - accuracy: 0.5800 - 185ms/epoch - 4ms/step
# epochs : 43
# 50/50 - 0s - loss: 1.0447 - accuracy: 0.6200 - 182ms/epoch - 4ms/step
# epochs : 44
# 50/50 - 0s - loss: 1.0189 - accuracy: 0.6000 - 183ms/epoch - 4ms/step
# epochs : 45
# 50/50 - 0s - loss: 1.3687 - accuracy: 0.4600 - 178ms/epoch - 4ms/step
# epochs : 46
# 50/50 - 0s - loss: 1.0475 - accuracy: 0.5800 - 177ms/epoch - 4ms/step
# epochs : 47
# 50/50 - 0s - loss: 0.8294 - accuracy: 0.6400 - 183ms/epoch - 4ms/step
# epochs : 48
# 50/50 - 0s - loss: 0.9760 - accuracy: 0.6200 - 186ms/epoch - 4ms/step
# epochs : 49
# 50/50 - 0s - loss: 0.9551 - accuracy: 0.5800 - 184ms/epoch - 4ms/step
# epochs : 50
# 50/50 - 0s - loss: 0.8697 - accuracy: 0.7200 - 187ms/epoch - 4ms/step
# epochs : 51
# 50/50 - 0s - loss: 0.8958 - accuracy: 0.6600 - 198ms/epoch - 4ms/step
# epochs : 52
# 50/50 - 0s - loss: 1.3014 - accuracy: 0.5600 - 191ms/epoch - 4ms/step
# epochs : 53
# 50/50 - 0s - loss: 0.9348 - accuracy: 0.6800 - 184ms/epoch - 4ms/step
# epochs : 54
# 50/50 - 0s - loss: 0.8190 - accuracy: 0.6800 - 183ms/epoch - 4ms/step
# epochs : 55
# 50/50 - 0s - loss: 0.8740 - accuracy: 0.6400 - 184ms/epoch - 4ms/step
# epochs : 56
# 50/50 - 0s - loss: 0.9289 - accuracy: 0.7000 - 212ms/epoch - 4ms/step
# epochs : 57
# 50/50 - 0s - loss: 0.6563 - accuracy: 0.8000 - 279ms/epoch - 6ms/step
# epochs : 58
# 50/50 - 0s - loss: 0.5408 - accuracy: 0.8800 - 280ms/epoch - 6ms/step
# epochs : 59
# 50/50 - 0s - loss: 0.6944 - accuracy: 0.7000 - 302ms/epoch - 6ms/step
# epochs : 60
# 50/50 - 0s - loss: 1.4883 - accuracy: 0.5200 - 272ms/epoch - 5ms/step
# epochs : 61
# 50/50 - 0s - loss: 1.0331 - accuracy: 0.6200 - 298ms/epoch - 6ms/step
# epochs : 62
# 50/50 - 0s - loss: 1.1682 - accuracy: 0.4800 - 296ms/epoch - 6ms/step
# epochs : 63
# 50/50 - 0s - loss: 0.9870 - accuracy: 0.6800 - 285ms/epoch - 6ms/step
# epochs : 64
# 50/50 - 0s - loss: 0.9699 - accuracy: 0.6000 - 296ms/epoch - 6ms/step
# epochs : 65
# 50/50 - 0s - loss: 0.8342 - accuracy: 0.6400 - 279ms/epoch - 6ms/step
# epochs : 66
# 50/50 - 0s - loss: 0.6981 - accuracy: 0.7400 - 282ms/epoch - 6ms/step
# epochs : 67
# 50/50 - 0s - loss: 0.5723 - accuracy: 0.8200 - 275ms/epoch - 5ms/step
# epochs : 68
# 50/50 - 0s - loss: 0.5426 - accuracy: 0.8200 - 191ms/epoch - 4ms/step
# epochs : 69
# 50/50 - 0s - loss: 0.4763 - accuracy: 0.8400 - 194ms/epoch - 4ms/step
# epochs : 70
# 50/50 - 0s - loss: 0.3936 - accuracy: 0.9000 - 200ms/epoch - 4ms/step
# epochs : 71
# 50/50 - 0s - loss: 0.6400 - accuracy: 0.7600 - 189ms/epoch - 4ms/step
# epochs : 72
# 50/50 - 0s - loss: 0.6122 - accuracy: 0.8000 - 178ms/epoch - 4ms/step
# epochs : 73
# 50/50 - 0s - loss: 0.6179 - accuracy: 0.8200 - 181ms/epoch - 4ms/step
# epochs : 74
# 50/50 - 0s - loss: 0.4188 - accuracy: 0.8800 - 184ms/epoch - 4ms/step
# epochs : 75
# 50/50 - 0s - loss: 0.5764 - accuracy: 0.7600 - 179ms/epoch - 4ms/step
# epochs : 76
# 50/50 - 0s - loss: 0.6762 - accuracy: 0.6600 - 171ms/epoch - 3ms/step
# epochs : 77
# 50/50 - 0s - loss: 0.6657 - accuracy: 0.8000 - 173ms/epoch - 3ms/step
# epochs : 78
# 50/50 - 0s - loss: 0.5513 - accuracy: 0.7800 - 189ms/epoch - 4ms/step
# epochs : 79
# 50/50 - 0s - loss: 0.3884 - accuracy: 0.9000 - 170ms/epoch - 3ms/step
# epochs : 80
# 50/50 - 0s - loss: 0.7301 - accuracy: 0.7200 - 180ms/epoch - 4ms/step
# epochs : 81
# 50/50 - 0s - loss: 0.7444 - accuracy: 0.7000 - 179ms/epoch - 4ms/step
# epochs : 82
# 50/50 - 0s - loss: 0.9360 - accuracy: 0.6600 - 196ms/epoch - 4ms/step
# epochs : 83
# 50/50 - 0s - loss: 0.5370 - accuracy: 0.8400 - 176ms/epoch - 4ms/step
# epochs : 84
# 50/50 - 0s - loss: 0.5897 - accuracy: 0.7600 - 179ms/epoch - 4ms/step
# epochs : 85
# 50/50 - 0s - loss: 0.4708 - accuracy: 0.8200 - 181ms/epoch - 4ms/step
# epochs : 86
# 50/50 - 0s - loss: 0.5628 - accuracy: 0.8600 - 178ms/epoch - 4ms/step
# epochs : 87
# 50/50 - 0s - loss: 0.4469 - accuracy: 0.8200 - 190ms/epoch - 4ms/step
# epochs : 88
# 50/50 - 0s - loss: 0.3555 - accuracy: 0.8800 - 190ms/epoch - 4ms/step
# epochs : 89
# 50/50 - 0s - loss: 0.3401 - accuracy: 0.8800 - 182ms/epoch - 4ms/step
# epochs : 90
# 50/50 - 0s - loss: 0.2631 - accuracy: 0.9400 - 188ms/epoch - 4ms/step
# epochs : 91
# 50/50 - 0s - loss: 0.2811 - accuracy: 0.9000 - 184ms/epoch - 4ms/step
# epochs : 92
# 50/50 - 0s - loss: 0.2340 - accuracy: 0.9600 - 184ms/epoch - 4ms/step
# epochs : 93
# 50/50 - 0s - loss: 0.2398 - accuracy: 0.9600 - 187ms/epoch - 4ms/step
# epochs : 94
# 50/50 - 0s - loss: 1.2354 - accuracy: 0.6000 - 175ms/epoch - 3ms/step
# epochs : 95
# 50/50 - 0s - loss: 0.7084 - accuracy: 0.7400 - 199ms/epoch - 4ms/step
# epochs : 96
# 50/50 - 0s - loss: 0.4871 - accuracy: 0.8600 - 180ms/epoch - 4ms/step
# epochs : 97
# 50/50 - 0s - loss: 0.4295 - accuracy: 0.8600 - 176ms/epoch - 4ms/step
# epochs : 98
# 50/50 - 0s - loss: 1.2821 - accuracy: 0.5600 - 167ms/epoch - 3ms/step
# epochs : 99
# 50/50 - 0s - loss: 0.6047 - accuracy: 0.8000 - 182ms/epoch - 4ms/step
# 50/50 [==============================] - 1s 4ms/step - loss: 0.6031 - accuracy: 0.8000
# accuracy: 80.00%
# 50/50 [==============================] - 1s 3ms/step
# one step prediction :  ['g8', 'e8', 'e4', 'f8', 'd8', 'd4', 'c8', 'd8', 'e8', 'f8', 'g8', 'e8', 'g4', 'g8', 'g8', 'e8', 'e8', 'f8', 'd8', 'd4', 'c8', 'e8', 'e8', 'g8', 'e8', 'e8', 'e4', 'd8', 'd8', 'f8', 'd8', 'e8', 'f4', 'e8', 'e8', 'e8', 'e8', 'e8', 'f8', 'f8', 'f4', 'g8', 'e8', 'e8', 'f8', 'd8', 'd4', 'c8', 'e8', 'g8', 'g8', 'e8', 'e8', 'e4']
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# full song prediction :  ['g8', 'e8', 'e4', 'f8', 'd8', 'd4', 'c8', 'd8', 'e8', 'f8', 'g8', 'e8', 'g4', 'g8', 'g8', 'e8', 'e8', 'e8', 'd8', 'd8', 'c8', 'e8', 'e8', 'e8', 'e8', 'e8', 'e8', 'e8', 'f4', 'e8', 'e8', 'e8', 'd8', 'd8', 'f4', 'e8', 'e8', 'e8', 'e8', 'e8', 'f8', 'g4', 'e8', 'e8', 'e4', 'f8', 'd8', 'd4', 'c8', 'e8', 'g8', 'g8', 'e8', 'e8']
